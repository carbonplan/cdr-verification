# %% [markdown]
# ### Steps
# 1. load all sheets with gspread
# 2. create .json template with pandas
# 3. for pathway in cdr-mrv doc:
#     1. read sheet
#     2. append to .json tempalte
#
# 4. export .json template

# %%
{
  "0": {
    "pathway_name": "Direct Air Capture",
    "pathway_description": "Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. A scelerisque purus semper eget duis at. Diam volutpat commodo sed egestas egestas fringilla phasellus faucibus. Proin nibh nisl condimentum id venenatis a. Libero enim sed faucibus turpis in eu mi. Lorem mollis aliquam ut porttitor leo a diam. Nunc eget lorem dolor sed viverra ipsum nunc aliquet bibendum. Ac auctor augue mauris augue neque. Tortor vitae purus faucibus ornare. Vitae turpis massa sed elementum tempus egestas sed sed risus. Nunc aliquet bibendum enim facilisis gravida neque convallis a. Ut enim blandit volutpat maecenas volutpat.",
    "VCL": "4,5",
    "equation": "1-2-3-4",
    "elements": "{\"diagram component\":{\"0\":1,\"1\":2,\"2\":3,\"3\":4,\"4\":5},\"category\":{\"0\":\"gross volume\",\"1\":\"net volume\",\"2\":\"net volume\",\"3\":\"net volume\",\"4\":\"permanence\"},\"name\":{\"0\":\"inj_co2\",\"1\":\"store_leak\",\"2\":\"energy_co2\",\"3\":\"mat_co2\",\"4\":\"stor_maint\"},\"description\":{\"0\":\"desc\",\"1\":\"desc\",\"2\":\"desc\",\"3\":\"desc\",\"4\":\"desc\"},\"comments\":{\"0\":\"comments\",\"1\":\"comments\",\"2\":\"comments\",\"3\":\"comments\",\"4\":\"comments\"},\"uncertainty type\":{\"0\":\"execution \",\"1\":\"execution \",\"2\":\"execution \",\"3\":\"execution \",\"4\":\"execution \"},\"uncertainty magnitude\":{\"0\":\"negligible\",\"1\":\"low to medium\",\"2\":\"low\",\"3\":\"low\",\"4\":\"low to medium\"},\"responsibility\":{\"0\":\"project\",\"1\":\"project\",\"2\":\"project\",\"3\":\"project\",\"4\":\"project\"},\"notes\":{\"0\":null,\"1\":null,\"2\":null,\"3\":null,\"4\":null},\"revisions\":{\"0\":null,\"1\":null,\"2\":null,\"3\":null,\"4\":null}}"
  }
}

# %%
# [
#     {
#         pathway: 'DAC',
#         description: 'TK',
#         VCL: [3,4],
#         equation: 'TK',
#         elements: [
#             {
#                 diagram_component: '1',
#                 category: 'gross_volume',
#                 name: 'inj_co2',
#                 description: 'TK',
#                 comments: 'TK',
#                 uncertainty_type: 'execution',
#                 uncertainty_magnitude: ['low', 'medium'],
#                 uncertainty_responsibility: 'project',
#                 revisions: 'TK',
#             },
#             // more elements
#             {...},
#             {...},
#         ],    
#     },
#     // more pathways
#     {...},
#     {...},
#     {...},
# ]

# %%
import pandas as pd
import pathlib
import gspread
from oauth2client.service_account import ServiceAccountCredentials
# gc = gspread.oauth()
import pprint

# %%
df = pd.read_csv("DAC_alt.csv")

# %%
df
# Out:
#          pathway name                                pathway description  VCL  \
# 0  Direct Air Capture  Lorem ipsum dolor sit amet, consectetur adipis...  4,5
# 1                 NaN                                                NaN  NaN
# 2                 NaN                                                NaN  NaN
# 3                 NaN                                                NaN  NaN
# 4                 NaN                                                NaN  NaN
#
#   equation  diagram component      category        name description  comments  \
# 0  1-2-3-4                  1  gross volume     inj_co2        desc  comments
# 1      NaN                  2    net volume  store_leak        desc  comments
# 2      NaN                  3    net volume  energy_co2        desc  comments
# 3      NaN                  4    net volume     mat_co2        desc  comments
# 4      NaN                  5    permanence  stor_maint        desc  comments
#
# ...

# %%
pathway_name = df['pathway name'].iloc[0]
pathway_description = df['pathway description'].iloc[0]
VCL = df['VCL'].iloc[0]
equation = df['equation'].iloc[0]
#temp
# df['description'] = 'desc'
# df['comments'] = 'comments'

method_df = df[df.columns[4::]]

# %%
template_dict = {"pathway_name":pathway_name, 
                 "pathway_description":pathway_description,
                 "VCL":VCL,
                 "equation":equation,
                 "elements": method_df.where(method_df.notnull(), "").to_dict(orient='records')
                }

# %%
method_df = method_df.where(df.notnull(), "")

# %%
method_df
# Out:
#    diagram component      category        name description  comments  \
# 0                  1  gross volume     inj_co2        desc  comments
# 1                  2    net volume  store_leak        desc  comments
# 2                  3    net volume  energy_co2        desc  comments
# 3                  4    net volume     mat_co2        desc  comments
# 4                  5    permanence  stor_maint        desc  comments
#
#   uncertainty type uncertainty magnitude responsibility notes revisions
# 0       execution             negligible        project
# 1       execution          low to medium        project
# 2       execution                    low        project
# 3       execution                    low        project
# 4       execution          low to medium        project

# %%
ls
# Out:
# DAC_alt.csv        asdf               sheets_to_json.py
# Untitled.ipynb     cdr_ex.json

# %%
import json
with open('cdr_ex.json', 'w') as fp:
    json.dump(template_dict, fp, indent=4)

# %%
cdf = pd.DataFrame.from_dict(template_dict, orient='index')
# df = pd.DataFrame.from_dict(user_dict, orient='index')

# %%
formatted_json_str = pprint.pformat(template_dict)
print(formatted_json_str)
pprint.pprint(template_dict)
# Out:
# {'VCL': '4,5',
#  'elements': '{"diagram '
#              'component":{"0":1,"1":2,"2":3,"3":4,"4":5},"category":{"0":"gross '
#              'volume","1":"net volume","2":"net volume","3":"net '
#              'volume","4":"permanence"},"name":{"0":"inj_co2","1":"store_leak","2":"energy_co2","3":"mat_co2","4":"stor_maint"},"description":{"0":"desc","1":"desc","2":"desc","3":"desc","4":"desc"},"comments":{"0":"comments","1":"comments","2":"comments","3":"comments","4":"comments"},"uncertainty '
#              'type":{"0":"execution ","1":"execution ","2":"execution '
#              '","3":"execution ","4":"execution "},"uncertainty '
#              'magnitude":{"0":"negligible","1":"low to '
#              'medium","2":"low","3":"low","4":"low to '
#              'medium"},"responsibility":{"0":"project","1":"project","2":"project","3":"project","4":"project"},"notes":{"0":null,"1":null,"2":null,"3":null,"4":null},"revisions":{"0":null,"1":null,"2":null,"3":null,"4":null}}',
# ...

# %%
template_dict
# Out:
# {'pathway_name': 'Direct Air Capture',
#  'pathway_description': 'Lorem ipsum dolor sit amet, consectetur adipiscing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua. A scelerisque purus semper eget duis at. Diam volutpat commodo sed egestas egestas fringilla phasellus faucibus. Proin nibh nisl condimentum id venenatis a. Libero enim sed faucibus turpis in eu mi. Lorem mollis aliquam ut porttitor leo a diam. Nunc eget lorem dolor sed viverra ipsum nunc aliquet bibendum. Ac auctor augue mauris augue neque. Tortor vitae purus faucibus ornare. Vitae turpis massa sed elementum tempus egestas sed sed risus. Nunc aliquet bibendum enim facilisis gravida neque convallis a. Ut enim blandit volutpat maecenas volutpat.',
#  'VCL': '4,5',
#  'equation': '1-2-3-4',
# ...
